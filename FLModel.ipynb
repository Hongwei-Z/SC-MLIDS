# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn 
from torch.utils.data import random_split, DataLoader, TensorDataset 
import flwr as fl
from flwr.common import Metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from collections import OrderedDict
from typing import List, Tuple
import sys
import time
import platform, cpuinfo, GPUtil, psutil
import warnings
warnings.simplefilter('ignore')

# %%
# print(f"OS: {platform.uname().system} {platform.uname().release}")
# print(f"CPU: {cpuinfo.get_cpu_info()['brand_raw']}")
# print(f"GPU: {GPUtil.getGPUs()[0].name}")
# print(f"Memory: {psutil.virtual_memory().total / (1024 ** 3):.2f} GB")

# %%
print("Python version:", sys.version)
print("Version info:", sys.version_info)
# Out:
# Python version: 3.11.4 (tags/v3.11.4:d2340ef, Jun  7 2023, 05:45:37) [MSC v.1934 64 bit (AMD64)]
# Version info: sys.version_info(major=3, minor=11, micro=4, releaselevel='final', serial=0)

# %%
DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(f"Training on {DEVICE} using PyTorch {torch.__version__} and Flower {fl.__version__}")
# Out:
# Training on cpu using PyTorch 2.0.1+cpu and Flower 1.5.0

# %%
NUM_CLIENTS = 3
EPOCHS = 10
ROUNDS = 3

BATCH_SIZE = 32
IN_FEATURES = 3
HIDDEN_LAYERS = 80
OUT_FEATURES = 2

# %%
def load_datasets():
    df = pd.read_csv('./datasets/sm_data.csv')
    
    feature = df.iloc[:, :-1]
    target = df.loc[:, 'target']
    feature = torch.Tensor(feature.to_numpy())
    target = torch.tensor(target.to_numpy())
    tensor_data = TensorDataset(feature, target)
    
    split_ratio = 0.8
    train_split = int(len(feature) * split_ratio)
    test_split = len(feature) - train_split
    while train_split % NUM_CLIENTS != 0:
        train_split -= 1
        test_split += 1
    train_set, test_set = random_split(tensor_data, [train_split, test_split])  

    # split_index = int(len(df) * split_ratio)
    # train_set = tensor_data.iloc[:split_index, :]
    # test_set = tensor_data.iloc[split_index:, :]
    
    part_size = len(train_set) // NUM_CLIENTS
    length = [part_size] * NUM_CLIENTS  # lengths for each client
    
    # Split the test set evenly into thirds, removing the remainders
    # random_choose = np.random.choice(train_set.index, (len(train_set) % NUM_CLIENTS), replace=False)
    # train_set = train_set.drop(random_choose)
    
    datasets = random_split(train_set, length, generator=torch.Generator().manual_seed(42))
    
    train_loader = []
    val_loader = []
    
    for data in datasets:
        val_length = len(data) // 10  # 10% for validation 
        
        train_length = len(data) - val_length
        length = [train_length, val_length]
        train_data, val_data = random_split(data, length, generator=torch.Generator().manual_seed(42))
        
        train_loader.append(DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True))
        val_loader.append(DataLoader(val_data, batch_size=BATCH_SIZE, shuffle=True))
    
    test_loader = DataLoader(test_set, batch_size=BATCH_SIZE, shuffle=True)
    return train_loader, val_loader, test_loader
    
train_loader, val_loader, test_loader = load_datasets()

# %%
class Network(nn.Module):
    
    def __init__(self, IN_FEATURES, HIDDEN_LAYERS, OUT_FEATURES):
        super().__init__()
        self.flatten = nn.Flatten()
        
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(IN_FEATURES, HIDDEN_LAYERS), 
            nn.ReLU(),
            nn.Linear(HIDDEN_LAYERS, HIDDEN_LAYERS), 
            nn.ReLU(),
            nn.Linear(HIDDEN_LAYERS, OUT_FEATURES), 
            nn.Softmax(dim=1)
        )
        
    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

# %%
def train(model, train_loader, epochs):
    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
    model.train()
    
    for epoch in range(1, epochs + 1): 
        correct, total, epoch_loss = 0, 0, 0.0
        
        for feature, target in train_loader:
            feature, target = feature.to(DEVICE), target.to(DEVICE)
            optimizer.zero_grad()
            output = model(feature)
            train_loss = criterion(output, target)
            train_loss.backward()
            optimizer.step()
            
            epoch_loss += train_loss
            total += target.size(0)
            correct += (torch.max(output.data, 1)[1] == target).sum().item()
            
        epoch_loss /= len(train_loader.dataset)
        epoch_accuracy = correct / total
        
        print(f"Epoch {epoch}/{EPOCHS}: train loss is {epoch_loss:.4f}, accuracy is {epoch_accuracy:.4f}.")

# %%
def test(model, test_loader):
    criterion = torch.nn.CrossEntropyLoss()
    model.eval()
    
    correct, total, loss = 0, 0, 0.0
    actual_labels = []
    predicted_labels = []
 
    with torch.no_grad():
        for feature, target in test_loader:
            feature, target = feature.to(DEVICE), target.to(DEVICE)
            output = model(feature)
            _, predicted = torch.max(output.data, 1)
            
            loss += criterion(output, target).item()
            # total += target.size(0)
            # correct += (predicted == target).sum().item()
            
            actual_labels.extend(target.cpu().numpy())
            predicted_labels.extend(predicted.cpu().numpy())
            
        loss /= len(test_loader.dataset)
        # accuracy = correct / total
        # return loss, accuracy
        
    accuracy = accuracy_score(actual_labels, predicted_labels)
    precision = precision_score(actual_labels, predicted_labels, average='weighted')
    recall = recall_score(actual_labels, predicted_labels, average='weighted')
    f1 = f1_score(actual_labels, predicted_labels, average='weighted')
    
    print("Testing Result:"
          "\n----------------------------------------------------------------------------------------")
    print(f"Loss: {accuracy:.4f}   Accuracy: {accuracy:.4f}   Precision: {precision:.4f}   Recall: {recall:.4f}   F1-Score: {f1:.4f}"
          f"\n----------------------------------------------------------------------------------------")

# %%
# PyTorch model testing
# train_loader = train_loader[1]
# val_loader = val_loader[1]
# model = Network(IN_FEATURES, HIDDEN_LAYERS, OUT_FEATURES).to(DEVICE)
# 
# train(model, train_loader, EPOCHS)
# test(model, val_loader)

# loss, accuracy = test(model, val_loader)
# print(f"Final test performance: \n\tloss: {loss:.8f}, accuracy: {accuracy:.8f}")

# %%
def get_parameters(model) -> List[np.ndarray]:
    return [val.cpu().numpy() for _, val in model.state_dict().items()]

def set_parameters(model, parameters: List[np.ndarray]):
    params_dict = zip(model.state_dict().keys(), parameters)
    state_dict = OrderedDict({k: torch.Tensor(v) for k, v in params_dict})
    model.load_state_dict(state_dict, strict=True)

# %%
class FlowerClient(fl.client.NumPyClient):
    def __init__(self, cid, model, train_loader, val_loader):
        self.cid = cid
        self.model = model
        self.train_loader = train_loader
        self.val_loader = val_loader

    def get_parameters(self, config):
        print(f"Client {self.cid} received the parameters.")
        return get_parameters(self.model)

    def fit(self, parameters, config):
        print(f"Client {self.cid} fit, config: {config}.")
        set_parameters(self.model, parameters)
        train(self.model, self.train_loader, epochs=EPOCHS)
        return get_parameters(self.model), len(self.train_loader), {}

    def evaluate(self, parameters, config):
        print(f"Client {self.cid} evaluate, config: {config}.")
        set_parameters(self.model, parameters)
        loss, accuracy = test(self.model, self.val_loader)
        return float(loss), len(self.val_loader), {'accuracy: ': float(accuracy)}

# %%
def client_fn(cid: str) -> FlowerClient:
    print(f"Client: {cid} -------------------------------------------------------------------------")
    model = Network(IN_FEATURES, HIDDEN_LAYERS, OUT_FEATURES).to(DEVICE)
    
    train_loader, val_loader, test_loader = load_datasets()
    train_loader = train_loader[int(cid)]
    val_loader = val_loader[int(cid)]
    
    return FlowerClient(cid, model, train_loader, val_loader)

# %%
def weighted_average(metrics: List[Tuple[int, Metrics]]) -> Metrics:
    accuracies = [num_examples * m['accuracy'] for num_examples, m in metrics]
    examples = [num_examples for num_examples, _ in metrics]
    return {'accuracy': sum(accuracies) / sum(examples)}

# %%
params = get_parameters(Network(IN_FEATURES, HIDDEN_LAYERS, OUT_FEATURES))

strategy = fl.server.strategy.FedAvg(
    fraction_fit=1.0,
    fraction_evaluate=1.0,
    min_fit_clients=NUM_CLIENTS,
    min_evaluate_clients=NUM_CLIENTS,
    min_available_clients=NUM_CLIENTS,
    initial_parameters=fl.common.ndarrays_to_parameters(params),
)

fl.simulation.start_simulation(
    client_fn=client_fn,
    num_clients=NUM_CLIENTS,
    config=fl.server.ServerConfig(num_rounds=ROUNDS),
    strategy=strategy,
)
# Out:
# INFO flwr 2023-10-25 17:48:27,516 | app.py:175 | Starting Flower simulation, config: ServerConfig(num_rounds=3, round_timeout=None)
# Exception in thread Thread-305:
# Traceback (most recent call last):
#   File "D:\Python\Python311\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "D:\Python\Python311\Lib\threading.py", line 1394, in run
#     self.function(*self.args, **self.kwargs)
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\app.py", line 258, in update_resources
#     num_max_actors = pool_size_from_resources(client_resources)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 107, in pool_size_from_resources
#     nodes = ray.nodes()
#             ^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\state.py", line 773, in nodes
#     return state.node_table()
#            ^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\state.py", line 148, in node_table
#     self._check_connected()
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\state.py", line 47, in _check_connected
#     raise ray.exceptions.RaySystemError(
# ray.exceptions.RaySystemError: System error: Ray has not been started yet. You can start Ray with 'ray.init()'.
# 2023-10-25 17:48:32,853	INFO worker.py:1621 -- Started a local Ray instance.
# INFO flwr 2023-10-25 17:48:35,702 | app.py:210 | Flower VCE: Ray initialized with resources: {'memory': 10895263335.0, 'object_store_memory': 5447631667.0, 'node:127.0.0.1': 1.0, 'GPU': 1.0, 'accelerator_type:G': 1.0, 'node:__internal_head__': 1.0, 'CPU': 20.0}
# INFO flwr 2023-10-25 17:48:35,702 | app.py:218 | No `client_resources` specified. Using minimal resources for clients.
# INFO flwr 2023-10-25 17:48:35,702 | app.py:224 | Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0.0}
# INFO flwr 2023-10-25 17:48:35,711 | app.py:270 | Flower VCE: Creating VirtualClientEngineActorPool with 20 actors
# INFO flwr 2023-10-25 17:48:35,711 | server.py:89 | Initializing global parameters
# INFO flwr 2023-10-25 17:48:35,711 | server.py:272 | Using initial parameters provided by strategy
# INFO flwr 2023-10-25 17:48:35,711 | server.py:91 | Evaluating initial parameters
# INFO flwr 2023-10-25 17:48:35,721 | server.py:104 | FL starting
# DEBUG flwr 2023-10-25 17:48:35,721 | server.py:222 | fit_round 1: strategy sampled 3 clients (out of 3)
# (DefaultActor pid=8920) Client: 0 -------------------------------------------------------------------------
# (DefaultActor pid=8920) Client 0 fit, config: {}.
# (DefaultActor pid=17248) Epoch 1/10: train loss is 0.0216, accuracy is 0.5237.
# (DefaultActor pid=11376) Client: 1 ------------------------------------------------------------------------- [repeated 2x across cluster]
# (DefaultActor pid=11376) Client 1 fit, config: {}. [repeated 2x across cluster]
# (DefaultActor pid=17248) Epoch 2/10: train loss is 0.0214, accuracy is 0.5461. [repeated 3x across cluster]
# (DefaultActor pid=17248) Epoch 3/10: train loss is 0.0211, accuracy is 0.5776. [repeated 3x across cluster]
# (DefaultActor pid=17248) Epoch 4/10: train loss is 0.0208, accuracy is 0.6005. [repeated 3x across cluster]
# (DefaultActor pid=17248) Epoch 5/10: train loss is 0.0207, accuracy is 0.6103. [repeated 3x across cluster]
# (DefaultActor pid=17248) Epoch 6/10: train loss is 0.0205, accuracy is 0.6154. [repeated 3x across cluster]
# (DefaultActor pid=17248) Epoch 7/10: train loss is 0.0205, accuracy is 0.6186. [repeated 3x across cluster]
# (DefaultActor pid=17248) Epoch 8/10: train loss is 0.0204, accuracy is 0.6204. [repeated 3x across cluster]
# (DefaultActor pid=17248) Epoch 9/10: train loss is 0.0203, accuracy is 0.6236. [repeated 3x across cluster]
# (DefaultActor pid=17248) Epoch 10/10: train loss is 0.0203, accuracy is 0.6256. [repeated 3x across cluster]
# DEBUG flwr 2023-10-25 17:49:43,901 | server.py:236 | fit_round 1 received 3 results and 0 failures
# WARNING flwr 2023-10-25 17:49:43,915 | fedavg.py:242 | No fit_metrics_aggregation_fn provided
# DEBUG flwr 2023-10-25 17:49:43,915 | server.py:173 | evaluate_round 1: strategy sampled 3 clients (out of 3)
# (DefaultActor pid=11376) Client: 0 -------------------------------------------------------------------------
# (DefaultActor pid=11376) Client 0 evaluate, config: {}.
# ERROR flwr 2023-10-25 17:49:44,662 | ray_client_proxy.py:147 | Traceback (most recent call last):
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 140, in _submit_job
#     res = self.actor_pool.get_client_result(self.cid, timeout)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 402, in get_client_result
#     return self._fetch_future_result(cid)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 288, in _fetch_future_result
#     res_cid, res = ray.get(future)  # type: (str, ClientRes)
#                    ^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\auto_init_hook.py", line 24, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 2524, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ClientException): ray::DefaultActor.run() (pid=8920, ip=127.0.0.1, actor_id=f0da5ba26db7223374e045f301000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x0000015904B5F9D0>)
#                   ^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 215, in evaluate
#     return maybe_call_evaluate(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\client\client.py", line 237, in maybe_call_evaluate
#     return client.evaluate(evaluate_ins)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\client\app.py", line 357, in _evaluate
#     results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Hongwei\AppData\Local\Temp\ipykernel_9420\701450191.py", line 21, in evaluate
# TypeError: cannot unpack non-iterable NoneType object
#
# The above exception was the direct cause of the following exception:
#
# ray::DefaultActor.run() (pid=8920, ip=127.0.0.1, actor_id=f0da5ba26db7223374e045f301000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x0000015904B5F9D0>)
#   File "python\ray\_raylet.pyx", line 1418, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1498, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1424, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1364, in ray._raylet.execute_task.function_executor
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\function_manager.py", line 726, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 464, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 72, in run
#     raise ClientException(str(message)) from ex
# flwr.simulation.ray_transport.ray_actor.ClientException:
# >>>>>>>A ClientException occurred.('\n\tSomething went wrong when running your client workload.\n\tClient 2 crashed when the DefaultActor was running its workload.\n\tException triggered on the client side: Traceback (most recent call last):\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\simulation\\ray_transport\\ray_actor.py", line 60, in run\n    job_results = job_fn()\n                  ^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\simulation\\ray_transport\\ray_client_proxy.py", line 215, in evaluate\n    return maybe_call_evaluate(\n           ^^^^^^^^^^^^^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\client\\client.py", line 237, in maybe_call_evaluate\n    return client.evaluate(evaluate_ins)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\client\\app.py", line 357, in _evaluate\n    results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore\n              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Hongwei\\AppData\\Local\\Temp\\ipykernel_9420\\701450191.py", line 21, in evaluate\nTypeError: cannot unpack non-iterable NoneType object\n',)
#
# ERROR flwr 2023-10-25 17:49:44,662 | ray_client_proxy.py:148 | ray::DefaultActor.run() (pid=8920, ip=127.0.0.1, actor_id=f0da5ba26db7223374e045f301000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x0000015904B5F9D0>)
#                   ^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 215, in evaluate
#     return maybe_call_evaluate(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\client\client.py", line 237, in maybe_call_evaluate
#     return client.evaluate(evaluate_ins)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\client\app.py", line 357, in _evaluate
#     results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Hongwei\AppData\Local\Temp\ipykernel_9420\701450191.py", line 21, in evaluate
# TypeError: cannot unpack non-iterable NoneType object
#
# The above exception was the direct cause of the following exception:
#
# ray::DefaultActor.run() (pid=8920, ip=127.0.0.1, actor_id=f0da5ba26db7223374e045f301000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x0000015904B5F9D0>)
#   File "python\ray\_raylet.pyx", line 1418, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1498, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1424, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1364, in ray._raylet.execute_task.function_executor
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\function_manager.py", line 726, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 464, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 72, in run
#     raise ClientException(str(message)) from ex
# flwr.simulation.ray_transport.ray_actor.ClientException:
# >>>>>>>A ClientException occurred.('\n\tSomething went wrong when running your client workload.\n\tClient 2 crashed when the DefaultActor was running its workload.\n\tException triggered on the client side: Traceback (most recent call last):\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\simulation\\ray_transport\\ray_actor.py", line 60, in run\n    job_results = job_fn()\n                  ^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\simulation\\ray_transport\\ray_client_proxy.py", line 215, in evaluate\n    return maybe_call_evaluate(\n           ^^^^^^^^^^^^^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\client\\client.py", line 237, in maybe_call_evaluate\n    return client.evaluate(evaluate_ins)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\client\\app.py", line 357, in _evaluate\n    results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore\n              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Hongwei\\AppData\\Local\\Temp\\ipykernel_9420\\701450191.py", line 21, in evaluate\nTypeError: cannot unpack non-iterable NoneType object\n',)
# ERROR flwr 2023-10-25 17:49:44,662 | ray_client_proxy.py:147 | Traceback (most recent call last):
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 140, in _submit_job
#     res = self.actor_pool.get_client_result(self.cid, timeout)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 402, in get_client_result
#     return self._fetch_future_result(cid)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 288, in _fetch_future_result
#     res_cid, res = ray.get(future)  # type: (str, ClientRes)
#                    ^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\auto_init_hook.py", line 24, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 2524, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ClientException): ray::DefaultActor.run() (pid=11376, ip=127.0.0.1, actor_id=a0913fe4ed9abc4a0f1fd00a01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x0000023509FE5F90>)
#                   ^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 215, in evaluate
#     return maybe_call_evaluate(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\client\client.py", line 237, in maybe_call_evaluate
#     return client.evaluate(evaluate_ins)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\client\app.py", line 357, in _evaluate
#     results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Hongwei\AppData\Local\Temp\ipykernel_9420\701450191.py", line 21, in evaluate
# TypeError: cannot unpack non-iterable NoneType object
#
# The above exception was the direct cause of the following exception:
#
# ray::DefaultActor.run() (pid=11376, ip=127.0.0.1, actor_id=a0913fe4ed9abc4a0f1fd00a01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x0000023509FE5F90>)
#   File "python\ray\_raylet.pyx", line 1418, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1498, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1424, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1364, in ray._raylet.execute_task.function_executor
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\function_manager.py", line 726, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 464, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 72, in run
#     raise ClientException(str(message)) from ex
# flwr.simulation.ray_transport.ray_actor.ClientException:
# >>>>>>>A ClientException occurred.('\n\tSomething went wrong when running your client workload.\n\tClient 0 crashed when the DefaultActor was running its workload.\n\tException triggered on the client side: Traceback (most recent call last):\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\simulation\\ray_transport\\ray_actor.py", line 60, in run\n    job_results = job_fn()\n                  ^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\simulation\\ray_transport\\ray_client_proxy.py", line 215, in evaluate\n    return maybe_call_evaluate(\n           ^^^^^^^^^^^^^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\client\\client.py", line 237, in maybe_call_evaluate\n    return client.evaluate(evaluate_ins)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\client\\app.py", line 357, in _evaluate\n    results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore\n              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Hongwei\\AppData\\Local\\Temp\\ipykernel_9420\\701450191.py", line 21, in evaluate\nTypeError: cannot unpack non-iterable NoneType object\n',)
#
# ERROR flwr 2023-10-25 17:49:44,662 | ray_client_proxy.py:148 | ray::DefaultActor.run() (pid=11376, ip=127.0.0.1, actor_id=a0913fe4ed9abc4a0f1fd00a01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x0000023509FE5F90>)
#                   ^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 215, in evaluate
#     return maybe_call_evaluate(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\client\client.py", line 237, in maybe_call_evaluate
#     return client.evaluate(evaluate_ins)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\client\app.py", line 357, in _evaluate
#     results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Hongwei\AppData\Local\Temp\ipykernel_9420\701450191.py", line 21, in evaluate
# TypeError: cannot unpack non-iterable NoneType object
#
# The above exception was the direct cause of the following exception:
#
# ray::DefaultActor.run() (pid=11376, ip=127.0.0.1, actor_id=a0913fe4ed9abc4a0f1fd00a01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x0000023509FE5F90>)
#   File "python\ray\_raylet.pyx", line 1418, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1498, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1424, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1364, in ray._raylet.execute_task.function_executor
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\function_manager.py", line 726, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 464, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 72, in run
#     raise ClientException(str(message)) from ex
# flwr.simulation.ray_transport.ray_actor.ClientException:
# >>>>>>>A ClientException occurred.('\n\tSomething went wrong when running your client workload.\n\tClient 0 crashed when the DefaultActor was running its workload.\n\tException triggered on the client side: Traceback (most recent call last):\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\simulation\\ray_transport\\ray_actor.py", line 60, in run\n    job_results = job_fn()\n                  ^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\simulation\\ray_transport\\ray_client_proxy.py", line 215, in evaluate\n    return maybe_call_evaluate(\n           ^^^^^^^^^^^^^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\client\\client.py", line 237, in maybe_call_evaluate\n    return client.evaluate(evaluate_ins)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\client\\app.py", line 357, in _evaluate\n    results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore\n              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Hongwei\\AppData\\Local\\Temp\\ipykernel_9420\\701450191.py", line 21, in evaluate\nTypeError: cannot unpack non-iterable NoneType object\n',)
# ERROR flwr 2023-10-25 17:49:44,662 | ray_client_proxy.py:147 | Traceback (most recent call last):
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 140, in _submit_job
#     res = self.actor_pool.get_client_result(self.cid, timeout)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 402, in get_client_result
#     return self._fetch_future_result(cid)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 288, in _fetch_future_result
#     res_cid, res = ray.get(future)  # type: (str, ClientRes)
#                    ^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\auto_init_hook.py", line 24, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 2524, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ClientException): ray::DefaultActor.run() (pid=17248, ip=127.0.0.1, actor_id=3208f19c7499ce3c8548f63701000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x0000022A8A68AA90>)
#                   ^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 215, in evaluate
#     return maybe_call_evaluate(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\client\client.py", line 237, in maybe_call_evaluate
#     return client.evaluate(evaluate_ins)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\client\app.py", line 357, in _evaluate
#     results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Hongwei\AppData\Local\Temp\ipykernel_9420\701450191.py", line 21, in evaluate
# TypeError: cannot unpack non-iterable NoneType object
#
# The above exception was the direct cause of the following exception:
#
# ray::DefaultActor.run() (pid=17248, ip=127.0.0.1, actor_id=3208f19c7499ce3c8548f63701000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x0000022A8A68AA90>)
#   File "python\ray\_raylet.pyx", line 1418, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1498, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1424, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1364, in ray._raylet.execute_task.function_executor
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\function_manager.py", line 726, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 464, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 72, in run
#     raise ClientException(str(message)) from ex
# flwr.simulation.ray_transport.ray_actor.ClientException:
# >>>>>>>A ClientException occurred.('\n\tSomething went wrong when running your client workload.\n\tClient 1 crashed when the DefaultActor was running its workload.\n\tException triggered on the client side: Traceback (most recent call last):\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\simulation\\ray_transport\\ray_actor.py", line 60, in run\n    job_results = job_fn()\n                  ^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\simulation\\ray_transport\\ray_client_proxy.py", line 215, in evaluate\n    return maybe_call_evaluate(\n           ^^^^^^^^^^^^^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\client\\client.py", line 237, in maybe_call_evaluate\n    return client.evaluate(evaluate_ins)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\client\\app.py", line 357, in _evaluate\n    results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore\n              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Hongwei\\AppData\\Local\\Temp\\ipykernel_9420\\701450191.py", line 21, in evaluate\nTypeError: cannot unpack non-iterable NoneType object\n',)
#
# ERROR flwr 2023-10-25 17:49:44,662 | ray_client_proxy.py:148 | ray::DefaultActor.run() (pid=17248, ip=127.0.0.1, actor_id=3208f19c7499ce3c8548f63701000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x0000022A8A68AA90>)
#                   ^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 215, in evaluate
#     return maybe_call_evaluate(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\client\client.py", line 237, in maybe_call_evaluate
#     return client.evaluate(evaluate_ins)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\client\app.py", line 357, in _evaluate
#     results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Hongwei\AppData\Local\Temp\ipykernel_9420\701450191.py", line 21, in evaluate
# TypeError: cannot unpack non-iterable NoneType object
#
# The above exception was the direct cause of the following exception:
#
# ray::DefaultActor.run() (pid=17248, ip=127.0.0.1, actor_id=3208f19c7499ce3c8548f63701000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x0000022A8A68AA90>)
#   File "python\ray\_raylet.pyx", line 1418, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1498, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1424, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1364, in ray._raylet.execute_task.function_executor
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\function_manager.py", line 726, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 464, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 72, in run
#     raise ClientException(str(message)) from ex
# flwr.simulation.ray_transport.ray_actor.ClientException:
# >>>>>>>A ClientException occurred.('\n\tSomething went wrong when running your client workload.\n\tClient 1 crashed when the DefaultActor was running its workload.\n\tException triggered on the client side: Traceback (most recent call last):\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\simulation\\ray_transport\\ray_actor.py", line 60, in run\n    job_results = job_fn()\n                  ^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\simulation\\ray_transport\\ray_client_proxy.py", line 215, in evaluate\n    return maybe_call_evaluate(\n           ^^^^^^^^^^^^^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\client\\client.py", line 237, in maybe_call_evaluate\n    return client.evaluate(evaluate_ins)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\client\\app.py", line 357, in _evaluate\n    results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore\n              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Hongwei\\AppData\\Local\\Temp\\ipykernel_9420\\701450191.py", line 21, in evaluate\nTypeError: cannot unpack non-iterable NoneType object\n',)
# DEBUG flwr 2023-10-25 17:49:44,662 | server.py:187 | evaluate_round 1 received 0 results and 3 failures
# DEBUG flwr 2023-10-25 17:49:44,662 | server.py:222 | fit_round 2: strategy sampled 3 clients (out of 3)
# (DefaultActor pid=11376) Testing Result:
# (DefaultActor pid=11376) ----------------------------------------------------------------------------------------
# (DefaultActor pid=11376) Loss: 0.6022   Accuracy: 0.6022   Precision: 0.6096   Recall: 0.6022   F1-Score: 0.5960
# (DefaultActor pid=11376) ----------------------------------------------------------------------------------------
# (DefaultActor pid=11376) Client 2 fit, config: {}.
# (DefaultActor pid=11376) Epoch 1/10: train loss is 0.0203, accuracy is 0.6244. [repeated 3x across cluster]
# (DefaultActor pid=17248) Client: 0 ------------------------------------------------------------------------- [repeated 5x across cluster]
# (DefaultActor pid=17248) Client 1 evaluate, config: {}. [repeated 2x across cluster]
# (DefaultActor pid=17248) Testing Result: [repeated 2x across cluster]
# (DefaultActor pid=17248) ---------------------------------------------------------------------------------------- [repeated 4x across cluster]
# (DefaultActor pid=17248) Loss: 0.6057   Accuracy: 0.6057   Precision: 0.6110   Recall: 0.6057   F1-Score: 0.5996 [repeated 2x across cluster]
# (DefaultActor pid=17248) Client 0 fit, config: {}. [repeated 2x across cluster]
# (DefaultActor pid=11376) Epoch 2/10: train loss is 0.0202, accuracy is 0.6279. [repeated 3x across cluster]
# (DefaultActor pid=11376) Epoch 3/10: train loss is 0.0202, accuracy is 0.6300. [repeated 3x across cluster]
# (DefaultActor pid=11376) Epoch 4/10: train loss is 0.0201, accuracy is 0.6310. [repeated 3x across cluster]
# (DefaultActor pid=11376) Epoch 5/10: train loss is 0.0201, accuracy is 0.6329. [repeated 3x across cluster]
# (DefaultActor pid=11376) Epoch 6/10: train loss is 0.0201, accuracy is 0.6341. [repeated 3x across cluster]
# (DefaultActor pid=11376) Epoch 7/10: train loss is 0.0201, accuracy is 0.6353. [repeated 3x across cluster]
# (DefaultActor pid=11376) Epoch 8/10: train loss is 0.0200, accuracy is 0.6367. [repeated 3x across cluster]
# (DefaultActor pid=11376) Epoch 9/10: train loss is 0.0200, accuracy is 0.6372. [repeated 3x across cluster]
# (DefaultActor pid=11376) Epoch 10/10: train loss is 0.0200, accuracy is 0.6377. [repeated 3x across cluster]
# DEBUG flwr 2023-10-25 17:50:41,629 | server.py:236 | fit_round 2 received 3 results and 0 failures
# DEBUG flwr 2023-10-25 17:50:41,632 | server.py:173 | evaluate_round 2: strategy sampled 3 clients (out of 3)
# (DefaultActor pid=11376) Client: 1 -------------------------------------------------------------------------
# (DefaultActor pid=11376) Client 1 evaluate, config: {}.
# ERROR flwr 2023-10-25 17:50:42,364 | ray_client_proxy.py:147 | Traceback (most recent call last):
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 140, in _submit_job
#     res = self.actor_pool.get_client_result(self.cid, timeout)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 402, in get_client_result
#     return self._fetch_future_result(cid)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 288, in _fetch_future_result
#     res_cid, res = ray.get(future)  # type: (str, ClientRes)
#                    ^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\auto_init_hook.py", line 24, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 2524, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ClientException): ray::DefaultActor.run() (pid=11376, ip=127.0.0.1, actor_id=a0913fe4ed9abc4a0f1fd00a01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x0000023509FE5F90>)
#                   ^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 215, in evaluate
#     return maybe_call_evaluate(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\client\client.py", line 237, in maybe_call_evaluate
#     return client.evaluate(evaluate_ins)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\client\app.py", line 357, in _evaluate
#     results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Hongwei\AppData\Local\Temp\ipykernel_9420\701450191.py", line 21, in evaluate
# TypeError: cannot unpack non-iterable NoneType object
#
# The above exception was the direct cause of the following exception:
#
# ray::DefaultActor.run() (pid=11376, ip=127.0.0.1, actor_id=a0913fe4ed9abc4a0f1fd00a01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x0000023509FE5F90>)
#   File "python\ray\_raylet.pyx", line 1418, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1498, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1424, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1364, in ray._raylet.execute_task.function_executor
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\function_manager.py", line 726, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 464, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 72, in run
#     raise ClientException(str(message)) from ex
# flwr.simulation.ray_transport.ray_actor.ClientException:
# >>>>>>>A ClientException occurred.('\n\tSomething went wrong when running your client workload.\n\tClient 1 crashed when the DefaultActor was running its workload.\n\tException triggered on the client side: Traceback (most recent call last):\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\simulation\\ray_transport\\ray_actor.py", line 60, in run\n    job_results = job_fn()\n                  ^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\simulation\\ray_transport\\ray_client_proxy.py", line 215, in evaluate\n    return maybe_call_evaluate(\n           ^^^^^^^^^^^^^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\client\\client.py", line 237, in maybe_call_evaluate\n    return client.evaluate(evaluate_ins)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\client\\app.py", line 357, in _evaluate\n    results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore\n              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Hongwei\\AppData\\Local\\Temp\\ipykernel_9420\\701450191.py", line 21, in evaluate\nTypeError: cannot unpack non-iterable NoneType object\n',)
#
# ERROR flwr 2023-10-25 17:50:42,376 | ray_client_proxy.py:148 | ray::DefaultActor.run() (pid=11376, ip=127.0.0.1, actor_id=a0913fe4ed9abc4a0f1fd00a01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x0000023509FE5F90>)
#                   ^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 215, in evaluate
#     return maybe_call_evaluate(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\client\client.py", line 237, in maybe_call_evaluate
#     return client.evaluate(evaluate_ins)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\client\app.py", line 357, in _evaluate
#     results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Hongwei\AppData\Local\Temp\ipykernel_9420\701450191.py", line 21, in evaluate
# TypeError: cannot unpack non-iterable NoneType object
#
# The above exception was the direct cause of the following exception:
#
# ray::DefaultActor.run() (pid=11376, ip=127.0.0.1, actor_id=a0913fe4ed9abc4a0f1fd00a01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x0000023509FE5F90>)
#   File "python\ray\_raylet.pyx", line 1418, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1498, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1424, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1364, in ray._raylet.execute_task.function_executor
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\function_manager.py", line 726, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 464, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 72, in run
#     raise ClientException(str(message)) from ex
# flwr.simulation.ray_transport.ray_actor.ClientException:
# >>>>>>>A ClientException occurred.('\n\tSomething went wrong when running your client workload.\n\tClient 1 crashed when the DefaultActor was running its workload.\n\tException triggered on the client side: Traceback (most recent call last):\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\simulation\\ray_transport\\ray_actor.py", line 60, in run\n    job_results = job_fn()\n                  ^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\simulation\\ray_transport\\ray_client_proxy.py", line 215, in evaluate\n    return maybe_call_evaluate(\n           ^^^^^^^^^^^^^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\client\\client.py", line 237, in maybe_call_evaluate\n    return client.evaluate(evaluate_ins)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\client\\app.py", line 357, in _evaluate\n    results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore\n              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Hongwei\\AppData\\Local\\Temp\\ipykernel_9420\\701450191.py", line 21, in evaluate\nTypeError: cannot unpack non-iterable NoneType object\n',)
# ERROR flwr 2023-10-25 17:50:42,379 | ray_client_proxy.py:147 | Traceback (most recent call last):
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 140, in _submit_job
#     res = self.actor_pool.get_client_result(self.cid, timeout)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 402, in get_client_result
#     return self._fetch_future_result(cid)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 288, in _fetch_future_result
#     res_cid, res = ray.get(future)  # type: (str, ClientRes)
#                    ^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\auto_init_hook.py", line 24, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 2524, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ClientException): ray::DefaultActor.run() (pid=8920, ip=127.0.0.1, actor_id=f0da5ba26db7223374e045f301000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x0000015904B5F9D0>)
#                   ^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 215, in evaluate
#     return maybe_call_evaluate(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\client\client.py", line 237, in maybe_call_evaluate
#     return client.evaluate(evaluate_ins)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\client\app.py", line 357, in _evaluate
#     results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Hongwei\AppData\Local\Temp\ipykernel_9420\701450191.py", line 21, in evaluate
# TypeError: cannot unpack non-iterable NoneType object
#
# The above exception was the direct cause of the following exception:
#
# ray::DefaultActor.run() (pid=8920, ip=127.0.0.1, actor_id=f0da5ba26db7223374e045f301000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x0000015904B5F9D0>)
#   File "python\ray\_raylet.pyx", line 1418, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1498, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1424, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1364, in ray._raylet.execute_task.function_executor
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\function_manager.py", line 726, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 464, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 72, in run
#     raise ClientException(str(message)) from ex
# flwr.simulation.ray_transport.ray_actor.ClientException:
# >>>>>>>A ClientException occurred.('\n\tSomething went wrong when running your client workload.\n\tClient 2 crashed when the DefaultActor was running its workload.\n\tException triggered on the client side: Traceback (most recent call last):\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\simulation\\ray_transport\\ray_actor.py", line 60, in run\n    job_results = job_fn()\n                  ^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\simulation\\ray_transport\\ray_client_proxy.py", line 215, in evaluate\n    return maybe_call_evaluate(\n           ^^^^^^^^^^^^^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\client\\client.py", line 237, in maybe_call_evaluate\n    return client.evaluate(evaluate_ins)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\client\\app.py", line 357, in _evaluate\n    results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore\n              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Hongwei\\AppData\\Local\\Temp\\ipykernel_9420\\701450191.py", line 21, in evaluate\nTypeError: cannot unpack non-iterable NoneType object\n',)
#
# ERROR flwr 2023-10-25 17:50:42,379 | ray_client_proxy.py:148 | ray::DefaultActor.run() (pid=8920, ip=127.0.0.1, actor_id=f0da5ba26db7223374e045f301000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x0000015904B5F9D0>)
#                   ^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 215, in evaluate
#     return maybe_call_evaluate(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\client\client.py", line 237, in maybe_call_evaluate
#     return client.evaluate(evaluate_ins)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\client\app.py", line 357, in _evaluate
#     results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Hongwei\AppData\Local\Temp\ipykernel_9420\701450191.py", line 21, in evaluate
# TypeError: cannot unpack non-iterable NoneType object
#
# The above exception was the direct cause of the following exception:
#
# ray::DefaultActor.run() (pid=8920, ip=127.0.0.1, actor_id=f0da5ba26db7223374e045f301000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x0000015904B5F9D0>)
#   File "python\ray\_raylet.pyx", line 1418, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1498, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1424, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1364, in ray._raylet.execute_task.function_executor
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\function_manager.py", line 726, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 464, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 72, in run
#     raise ClientException(str(message)) from ex
# flwr.simulation.ray_transport.ray_actor.ClientException:
# >>>>>>>A ClientException occurred.('\n\tSomething went wrong when running your client workload.\n\tClient 2 crashed when the DefaultActor was running its workload.\n\tException triggered on the client side: Traceback (most recent call last):\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\simulation\\ray_transport\\ray_actor.py", line 60, in run\n    job_results = job_fn()\n                  ^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\simulation\\ray_transport\\ray_client_proxy.py", line 215, in evaluate\n    return maybe_call_evaluate(\n           ^^^^^^^^^^^^^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\client\\client.py", line 237, in maybe_call_evaluate\n    return client.evaluate(evaluate_ins)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\client\\app.py", line 357, in _evaluate\n    results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore\n              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Hongwei\\AppData\\Local\\Temp\\ipykernel_9420\\701450191.py", line 21, in evaluate\nTypeError: cannot unpack non-iterable NoneType object\n',)
# ERROR flwr 2023-10-25 17:50:42,379 | ray_client_proxy.py:147 | Traceback (most recent call last):
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 140, in _submit_job
#     res = self.actor_pool.get_client_result(self.cid, timeout)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 2524, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ClientException): ray::DefaultActor.run() (pid=8920, ip=127.0.0.1, actor_id=f0da5ba26db7223374e045f301000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x0000015904B5F9D0>)
#                   ^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 215, in evaluate
#     return maybe_call_evaluate(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\client\client.py", line 237, in maybe_call_evaluate
#     return client.evaluate(evaluate_ins)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\client\app.py", line 357, in _evaluate
#     results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Hongwei\AppData\Local\Temp\ipykernel_9420\701450191.py", line 21, in evaluate
# TypeError: cannot unpack non-iterable NoneType object
#
# The above exception was the direct cause of the following exception:
#
# ray::DefaultActor.run() (pid=8920, ip=127.0.0.1, actor_id=f0da5ba26db7223374e045f301000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x0000015904B5F9D0>)
#   File "python\ray\_raylet.pyx", line 1418, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1498, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1424, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1364, in ray._raylet.execute_task.function_executor
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\function_manager.py", line 726, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 464, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 72, in run
#     raise ClientException(str(message)) from ex
# flwr.simulation.ray_transport.ray_actor.ClientException:
# >>>>>>>A ClientException occurred.('\n\tSomething went wrong when running your client workload.\n\tClient 1 crashed when the DefaultActor was running its workload.\n\tException triggered on the client side: Traceback (most recent call last):\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\simulation\\ray_transport\\ray_actor.py", line 60, in run\n    job_results = job_fn()\n                  ^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\simulation\\ray_transport\\ray_client_proxy.py", line 215, in evaluate\n    return maybe_call_evaluate(\n           ^^^^^^^^^^^^^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\client\\client.py", line 237, in maybe_call_evaluate\n    return client.evaluate(evaluate_ins)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\client\\app.py", line 357, in _evaluate\n    results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore\n              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Hongwei\\AppData\\Local\\Temp\\ipykernel_9420\\701450191.py", line 21, in evaluate\nTypeError: cannot unpack non-iterable NoneType object\n',)
#
# ERROR flwr 2023-10-25 17:51:40,257 | ray_client_proxy.py:147 | Traceback (most recent call last):
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 140, in _submit_job
#     res = self.actor_pool.get_client_result(self.cid, timeout)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 402, in get_client_result
#     return self._fetch_future_result(cid)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 288, in _fetch_future_result
#     res_cid, res = ray.get(future)  # type: (str, ClientRes)
#                    ^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\auto_init_hook.py", line 24, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 2524, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ClientException): ray::DefaultActor.run() (pid=17248, ip=127.0.0.1, actor_id=3208f19c7499ce3c8548f63701000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x0000022A8A68AA90>)
#                   ^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 215, in evaluate
#     return maybe_call_evaluate(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\client\client.py", line 237, in maybe_call_evaluate
#     return client.evaluate(evaluate_ins)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\client\app.py", line 357, in _evaluate
#     results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Hongwei\AppData\Local\Temp\ipykernel_9420\701450191.py", line 21, in evaluate
# TypeError: cannot unpack non-iterable NoneType object
#
# The above exception was the direct cause of the following exception:
#
# ray::DefaultActor.run() (pid=17248, ip=127.0.0.1, actor_id=3208f19c7499ce3c8548f63701000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x0000022A8A68AA90>)
#   File "python\ray\_raylet.pyx", line 1418, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1498, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1424, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1364, in ray._raylet.execute_task.function_executor
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\function_manager.py", line 726, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 464, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 72, in run
#     raise ClientException(str(message)) from ex
# flwr.simulation.ray_transport.ray_actor.ClientException:
# >>>>>>>A ClientException occurred.('\n\tSomething went wrong when running your client workload.\n\tClient 0 crashed when the DefaultActor was running its workload.\n\tException triggered on the client side: Traceback (most recent call last):\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\simulation\\ray_transport\\ray_actor.py", line 60, in run\n    job_results = job_fn()\n                  ^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\simulation\\ray_transport\\ray_client_proxy.py", line 215, in evaluate\n    return maybe_call_evaluate(\n           ^^^^^^^^^^^^^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\client\\client.py", line 237, in maybe_call_evaluate\n    return client.evaluate(evaluate_ins)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\client\\app.py", line 357, in _evaluate\n    results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore\n              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Hongwei\\AppData\\Local\\Temp\\ipykernel_9420\\701450191.py", line 21, in evaluate\nTypeError: cannot unpack non-iterable NoneType object\n',)
#
# ERROR flwr 2023-10-25 17:51:40,257 | ray_client_proxy.py:148 | ray::DefaultActor.run() (pid=8920, ip=127.0.0.1, actor_id=f0da5ba26db7223374e045f301000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x0000015904B5F9D0>)
#                   ^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 215, in evaluate
#     return maybe_call_evaluate(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\client\client.py", line 237, in maybe_call_evaluate
#     return client.evaluate(evaluate_ins)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\client\app.py", line 357, in _evaluate
#     results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Hongwei\AppData\Local\Temp\ipykernel_9420\701450191.py", line 21, in evaluate
# TypeError: cannot unpack non-iterable NoneType object
#
# The above exception was the direct cause of the following exception:
#
# ray::DefaultActor.run() (pid=8920, ip=127.0.0.1, actor_id=f0da5ba26db7223374e045f301000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x0000015904B5F9D0>)
#   File "python\ray\_raylet.pyx", line 1418, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1498, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1424, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1364, in ray._raylet.execute_task.function_executor
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\function_manager.py", line 726, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 464, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 72, in run
#     raise ClientException(str(message)) from ex
# flwr.simulation.ray_transport.ray_actor.ClientException:
# >>>>>>>A ClientException occurred.('\n\tSomething went wrong when running your client workload.\n\tClient 1 crashed when the DefaultActor was running its workload.\n\tException triggered on the client side: Traceback (most recent call last):\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\simulation\\ray_transport\\ray_actor.py", line 60, in run\n    job_results = job_fn()\n                  ^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\simulation\\ray_transport\\ray_client_proxy.py", line 215, in evaluate\n    return maybe_call_evaluate(\n           ^^^^^^^^^^^^^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\client\\client.py", line 237, in maybe_call_evaluate\n    return client.evaluate(evaluate_ins)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\client\\app.py", line 357, in _evaluate\n    results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore\n              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Hongwei\\AppData\\Local\\Temp\\ipykernel_9420\\701450191.py", line 21, in evaluate\nTypeError: cannot unpack non-iterable NoneType object\n',)
# ERROR flwr 2023-10-25 17:51:40,285 | ray_client_proxy.py:148 | ray::DefaultActor.run() (pid=17248, ip=127.0.0.1, actor_id=3208f19c7499ce3c8548f63701000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x0000022A8A68AA90>)
#                   ^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 215, in evaluate
#     return maybe_call_evaluate(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\client\client.py", line 237, in maybe_call_evaluate
#     return client.evaluate(evaluate_ins)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\client\app.py", line 357, in _evaluate
#     results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Hongwei\AppData\Local\Temp\ipykernel_9420\701450191.py", line 21, in evaluate
# TypeError: cannot unpack non-iterable NoneType object
#
# The above exception was the direct cause of the following exception:
#
# ray::DefaultActor.run() (pid=17248, ip=127.0.0.1, actor_id=3208f19c7499ce3c8548f63701000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x0000022A8A68AA90>)
#   File "python\ray\_raylet.pyx", line 1418, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1498, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1424, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1364, in ray._raylet.execute_task.function_executor
#   File "D:\Python\Python311\Lib\site-packages\ray\_private\function_manager.py", line 726, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 464, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 72, in run
#     raise ClientException(str(message)) from ex
# flwr.simulation.ray_transport.ray_actor.ClientException:
# >>>>>>>A ClientException occurred.('\n\tSomething went wrong when running your client workload.\n\tClient 0 crashed when the DefaultActor was running its workload.\n\tException triggered on the client side: Traceback (most recent call last):\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\simulation\\ray_transport\\ray_actor.py", line 60, in run\n    job_results = job_fn()\n                  ^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\simulation\\ray_transport\\ray_client_proxy.py", line 215, in evaluate\n    return maybe_call_evaluate(\n           ^^^^^^^^^^^^^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\client\\client.py", line 237, in maybe_call_evaluate\n    return client.evaluate(evaluate_ins)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "D:\\Python\\Python311\\Lib\\site-packages\\flwr\\client\\app.py", line 357, in _evaluate\n    results = self.numpy_client.evaluate(parameters, ins.config)  # type: ignore\n              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\Hongwei\\AppData\\Local\\Temp\\ipykernel_9420\\701450191.py", line 21, in evaluate\nTypeError: cannot unpack non-iterable NoneType object\n',)
# DEBUG flwr 2023-10-25 17:51:40,285 | server.py:187 | evaluate_round 3 received 0 results and 3 failures
# INFO flwr 2023-10-25 17:51:40,285 | server.py:153 | FL finished in 184.56572589999996
# INFO flwr 2023-10-25 17:51:40,285 | app.py:225 | app_fit: losses_distributed []
# INFO flwr 2023-10-25 17:51:40,285 | app.py:226 | app_fit: metrics_distributed_fit {}
# INFO flwr 2023-10-25 17:51:40,285 | app.py:227 | app_fit: metrics_distributed {}
# INFO flwr 2023-10-25 17:51:40,285 | app.py:228 | app_fit: losses_centralized []
# INFO flwr 2023-10-25 17:51:40,285 | app.py:229 | app_fit: metrics_centralized {}
# (DefaultActor pid=11376) Testing Result:
# (DefaultActor pid=11376) ----------------------------------------------------------------------------------------
# (DefaultActor pid=11376) Loss: 0.6444   Accuracy: 0.6444   Precision: 0.6444   Recall: 0.6444   F1-Score: 0.6444
# (DefaultActor pid=11376) ----------------------------------------------------------------------------------------

# %% [markdown]
# Citation:
# https://flower.dev/docs/framework/tutorial-series-get-started-with-flower-pytorch.html
# https://pytorch.org/tutorials/beginner/basics/quickstart_tutorial.html
